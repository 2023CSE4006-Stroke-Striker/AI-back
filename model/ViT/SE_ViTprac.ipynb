# %%
import numpy as np

from tqdm import tqdm, trange

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision.transforms as transforms
from torchvision.datasets.mnist import MNIST

np.random.seed(0)
torch.manual_seed(0)

# %%
import os
import pandas as pd
from torchvision.io import read_image

# %%
class StrokeImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file, names=['file_name', 'label'])
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path)
        image = transforms.Resize((150, 150))(image)
        image = transforms.Grayscale()(image)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
# Loading data
# transform = transforms.Compose([
#     transforms.Resize((150, 150)),
#     transforms.ToTensor(),
# ])

img_dir = "/content/drive/MyDrive/main/datasets"
annotation_file = "/content/drive/MyDrive/main/datasets/annotation_file.csv"

dataset = StrokeImageDataset(annotation_file, img_dir)
dataset_size = len(dataset)

train_size = int(dataset_size * 0.8)
test_size = dataset_size - train_size

    # random_split 사용
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, shuffle=True, batch_size=16)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=16)


    # 이미지와 정답(label)을 표시합니다.
for index, (images, labels) in enumerate(train_loader):
    print(f"{index}/{len(train_loader)}", end=' ')
    print("x shape:", images.shape, end=' ')
    print("y shape:", labels.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 0/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 1/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 2/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 3/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 4/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 5/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 6/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 7/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 8/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 9/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 10/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 11/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 12/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 13/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 14/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 15/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 16/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 17/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 18/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 19/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 20/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 21/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 22/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 23/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 24/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 25/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 26/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 27/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 28/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 29/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 30/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 31/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 32/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 33/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 34/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 35/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 36/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 37/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 38/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 39/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 40/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 41/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 42/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 43/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 44/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 45/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 46/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 47/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 48/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 49/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 50/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 51/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 52/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 53/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 54/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 55/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 56/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 57/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 58/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 59/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 60/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 61/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 62/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 63/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 64/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 65/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 66/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 67/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 68/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 69/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 70/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 71/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 72/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 73/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 74/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 75/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 76/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 77/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 78/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 79/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 80/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 81/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 82/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 83/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 84/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 85/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 86/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 87/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 88/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 89/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 90/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 91/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 92/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 93/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 94/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 95/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 96/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 97/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 98/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 99/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 100/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 101/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 102/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 103/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 104/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 105/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 106/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 107/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 108/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 109/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 110/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 111/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 112/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 113/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 114/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 115/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 116/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 117/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 118/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 119/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 120/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 121/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 122/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 123/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 124/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 125/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 126/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 127/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 128/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 129/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 130/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 131/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 132/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 133/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 134/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 135/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 136/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 137/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 138/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 139/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 140/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 141/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 142/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 143/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 144/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 145/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 146/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 147/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 148/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 149/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 150/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 151/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 152/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 153/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 154/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 155/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 156/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 157/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 158/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 159/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 160/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 161/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 162/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 163/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 164/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 165/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 166/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 167/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 168/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 169/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 170/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 171/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 172/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 173/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 174/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 175/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 176/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 177/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 178/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 179/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 180/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 181/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 182/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 183/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 184/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 185/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 186/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 187/189 x shape: torch.Size([16, 1, 150, 150]) y shape: torch.Size([16])
# 188/189 x shape: torch.Size([8, 1, 150, 150]) y shape: torch.Size([8])

# %%
def main():
    # Loading data

    img_dir = "/content/drive/MyDrive/main/datasets"
    annotation_file = "/content/drive/MyDrive/main/datasets/annotation_file.csv"

    dataset = StrokeImageDataset(annotation_file, img_dir)
    dataset_size = len(dataset)

    train_size = int(dataset_size * 0.8)
    test_size = dataset_size - train_size

    # random_split 사용
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, shuffle=True, batch_size=16)
    test_loader = DataLoader(test_dataset, shuffle=False, batch_size=16)

    # Defining model and training options
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")
    model = MyViT((1, 150, 150), n_patches=50, n_blocks=2, hidden_d=4, n_heads=2, out_d=2).to(device)
    N_EPOCHS = 5
    LR = 0.005

    # Training loop
    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")

    # Test loop
    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)
        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
class MyViT(nn.Module):
    def __init__(self, chw, n_patches=100, n_blocks=4, hidden_d=3, n_heads=4, out_d=2):
        # Super constructor
        super(MyViT, self).__init__()

        # Attributes
        self.chw = chw # ( C , H , W )
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d

        # Input and patches sizes
        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # 1) Linear mapper
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)

        # 2) Learnable classification token
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))

        # 3) Positional embedding
        self.register_buffer('positional_embeddings', get_positional_embeddings(n_patches ** 2 + 1, hidden_d), persistent=False)

        # 4) Transformer encoder blocks
        self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])

        # 5) Classification MLPk
        self.mlp = nn.Sequential(
            nn.Linear(self.hidden_d, out_d),
            nn.Softmax(dim=-1)
        )

    def forward(self, images):
        # Dividing images into patches
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)

        # Running linear layer tokenization
        # Map the vector corresponding to each patch to the hidden size dimension
        tokens = self.linear_mapper(patches)

        # Adding classification token to the tokens
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)

        # Adding positional embedding
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        # Transformer Blocks
        for block in self.blocks:
            out = block(out)

        # Getting the classification token only
        out = out[:, 0]

        return self.mlp(out) # Map to output dimension, output category distribution

# %%
def patchify(images, n_patches):
    n, c, h, w = images.shape

    assert h == w, "Patchify method is implemented for square images only"

    patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches

# %%
def get_positional_embeddings(sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result

# %%
class MyMSA(nn.Module):
    def __init__(self, d, n_heads=4):
        super(MyMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0, f"Can't divide dimension {d} into {n_heads} heads"

        d_head = int(d / n_heads)
        self.q_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):
        # Sequences has shape (N, seq_length, token_dim)
        # We go into shape    (N, seq_length, n_heads, token_dim / n_heads)
        # And come back to    (N, seq_length, item_dim)  (through concatenation)
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out

# %%
main()
# Out:
# Using device:  cuda (Tesla T4)
# Training:   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/189 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
#
# Epoch 1 in training:   1%|          | 1/189 [00:07<23:25,  7.48s/it]
# Epoch 1 in training:   1%|          | 2/189 [00:11<16:14,  5.21s/it]
# Epoch 1 in training:   2%|▏         | 3/189 [00:15<14:58,  4.83s/it]
# Epoch 1 in training:   2%|▏         | 4/189 [00:20<15:08,  4.91s/it]
# Epoch 1 in training:   3%|▎         | 5/189 [00:25<15:28,  5.04s/it]
# Epoch 2 in training:  91%|█████████ | 172/189 [06:12<00:37,  2.22s/it]
# Epoch 2 in training:  92%|█████████▏| 173/189 [06:14<00:35,  2.21s/it]
# Epoch 2 in training:  92%|█████████▏| 174/189 [06:16<00:33,  2.21s/it]
# Epoch 2 in training:  93%|█████████▎| 175/189 [06:19<00:31,  2.22s/it]
# Epoch 2 in training:  93%|█████████▎| 176/189 [06:21<00:28,  2.21s/it]
# Epoch 2 in training:  94%|█████████▎| 177/189 [06:23<00:26,  2.20s/it]
# Epoch 2 in training:  94%|█████████▍| 178/189 [06:25<00:24,  2.19s/it]
# Epoch 2 in training:  95%|█████████▍| 179/189 [06:27<00:21,  2.19s/it]
# Epoch 2 in training:  95%|█████████▌| 180/189 [06:30<00:19,  2.22s/it]
# Epoch 2 in training:  96%|█████████▌| 181/189 [06:32<00:18,  2.27s/it]
# Epoch 2 in training:  96%|█████████▋| 182/189 [06:34<00:15,  2.26s/it]
# Epoch 2 in training:  97%|█████████▋| 183/189 [06:36<00:13,  2.23s/it]
# Epoch 2 in training:  97%|█████████▋| 184/189 [06:39<00:11,  2.24s/it]
# Epoch 2 in training:  98%|█████████▊| 185/189 [06:41<00:08,  2.22s/it]
# Epoch 2 in training:  98%|█████████▊| 186/189 [06:43<00:06,  2.21s/it]
# Epoch 2 in training:  99%|█████████▉| 187/189 [06:45<00:04,  2.21s/it]
# Epoch 2 in training:  99%|█████████▉| 188/189 [06:47<00:02,  2.20s/it]
# Epoch 2 in training: 100%|██████████| 189/189 [06:49<00:00,  1.87s/it]
# Training:  40%|████      | 2/5 [21:22<30:00, 600.16s/it]
# Epoch 2/5 loss: 0.61
# Epoch 3 in training:   0%|          | 0/189 [00:00<?, ?it/s]
# Epoch 3 in training:   1%|          | 1/189 [00:02<06:45,  2.15s/it]
# Epoch 3 in training:   1%|          | 2/189 [00:04<06:45,  2.17s/it]
# Epoch 3 in training:   2%|▏         | 3/189 [00:06<06:46,  2.18s/it]
# Epoch 3 in training:   2%|▏         | 4/189 [00:08<06:42,  2.17s/it]
# Epoch 3 in training:   3%|▎         | 5/189 [00:10<06:41,  2.18s/it]
# Epoch 3 in training:   3%|▎         | 6/189 [00:13<06:45,  2.22s/it]
# Epoch 3 in training:   4%|▎         | 7/189 [00:15<06:47,  2.24s/it]
# Epoch 3 in training:   4%|▍         | 8/189 [00:17<06:46,  2.25s/it]
# Epoch 3 in training:   5%|▍         | 9/189 [00:19<06:42,  2.24s/it]
# Epoch 3 in training:   5%|▌         | 10/189 [00:22<06:38,  2.23s/it]
# Epoch 3 in training:   6%|▌         | 11/189 [00:24<06:34,  2.22s/it]
# Epoch 3 in training:   6%|▋         | 12/189 [00:26<06:29,  2.20s/it]
# Epoch 3 in training:   7%|▋         | 13/189 [00:28<06:24,  2.18s/it]
# Epoch 3 in training:   7%|▋         | 14/189 [00:30<06:21,  2.18s/it]
# Epoch 3 in training:   8%|▊         | 15/189 [00:33<06:19,  2.18s/it]
# Epoch 3 in training:   8%|▊         | 16/189 [00:35<06:16,  2.18s/it]
# Epoch 3 in training:  84%|████████▍ | 159/189 [05:42<01:03,  2.11s/it]
# Epoch 3 in training:  85%|████████▍ | 160/189 [05:44<01:01,  2.11s/it]
# Epoch 3 in training:  85%|████████▌ | 161/189 [05:46<00:59,  2.11s/it]
# Epoch 3 in training:  86%|████████▌ | 162/189 [05:48<00:57,  2.12s/it]
# Epoch 3 in training:  86%|████████▌ | 163/189 [05:51<00:55,  2.13s/it]
# Epoch 3 in training:  87%|████████▋ | 164/189 [05:53<00:53,  2.12s/it]
# Epoch 3 in training:  87%|████████▋ | 165/189 [05:55<00:50,  2.11s/it]
# Epoch 3 in training:  88%|████████▊ | 166/189 [05:57<00:48,  2.11s/it]
# Epoch 3 in training:  88%|████████▊ | 167/189 [05:59<00:46,  2.10s/it]
# Epoch 3 in training:  89%|████████▉ | 168/189 [06:01<00:44,  2.10s/it]
# Epoch 3 in training:  89%|████████▉ | 169/189 [06:03<00:42,  2.11s/it]
# Epoch 3 in training:  90%|████████▉ | 170/189 [06:05<00:39,  2.09s/it]
# Epoch 3 in training:  90%|█████████ | 171/189 [06:07<00:37,  2.09s/it]
# Epoch 3 in training:  91%|█████████ | 172/189 [06:09<00:35,  2.09s/it]
# Epoch 3 in training:  92%|█████████▏| 173/189 [06:11<00:33,  2.08s/it]
# Epoch 3 in training:  92%|█████████▏| 174/189 [06:13<00:31,  2.08s/it]
# Epoch 3 in training:  93%|█████████▎| 175/189 [06:16<00:29,  2.11s/it]
# Epoch 3 in training:  93%|█████████▎| 176/189 [06:18<00:27,  2.12s/it]
# Epoch 3 in training:  94%|█████████▎| 177/189 [06:20<00:25,  2.11s/it]
# Epoch 3 in training:  94%|█████████▍| 178/189 [06:22<00:23,  2.11s/it]
# Epoch 3 in training:  95%|█████████▍| 179/189 [06:24<00:20,  2.10s/it]
# Epoch 3 in training:  95%|█████████▌| 180/189 [06:26<00:18,  2.08s/it]
# Epoch 3 in training:  96%|█████████▌| 181/189 [06:28<00:16,  2.10s/it]
# Epoch 3 in training:  96%|█████████▋| 182/189 [06:30<00:14,  2.13s/it]
# Epoch 3 in training:  97%|█████████▋| 183/189 [06:33<00:12,  2.12s/it]
# Epoch 3 in training:  97%|█████████▋| 184/189 [06:35<00:10,  2.11s/it]
# Epoch 3 in training:  98%|█████████▊| 185/189 [06:37<00:08,  2.10s/it]
# Epoch 3 in training:  98%|█████████▊| 186/189 [06:39<00:06,  2.10s/it]
# Epoch 3 in training:  99%|█████████▉| 187/189 [06:41<00:04,  2.11s/it]
# Epoch 3 in training:  99%|█████████▉| 188/189 [06:43<00:02,  2.12s/it]
# Epoch 3 in training: 100%|██████████| 189/189 [06:44<00:00,  1.82s/it]
# Training:  60%|██████    | 3/5 [28:06<17:01, 510.92s/it]
# Epoch 3/5 loss: 0.60
# Epoch 4 in training:   0%|          | 0/189 [00:00<?, ?it/s]
# Epoch 4 in training:   1%|          | 1/189 [00:02<06:32,  2.09s/it]
# Epoch 4 in training:   1%|          | 2/189 [00:04<06:33,  2.10s/it]
# Epoch 4 in training:   2%|▏         | 3/189 [00:06<06:31,  2.11s/it]
# Epoch 4 in training:  90%|█████████ | 171/189 [05:59<00:37,  2.10s/it]
# Epoch 4 in training:  91%|█████████ | 172/189 [06:02<00:36,  2.12s/it]
# Epoch 4 in training:  92%|█████████▏| 173/189 [06:04<00:34,  2.13s/it]
# Epoch 4 in training:  92%|█████████▏| 174/189 [06:06<00:31,  2.11s/it]
# Epoch 4 in training:  93%|█████████▎| 175/189 [06:08<00:29,  2.09s/it]
# Epoch 4 in training:  93%|█████████▎| 176/189 [06:10<00:27,  2.09s/it]
# Epoch 4 in training:  94%|█████████▎| 177/189 [06:12<00:25,  2.09s/it]
# Epoch 4 in training:  94%|█████████▍| 178/189 [06:14<00:23,  2.10s/it]
# Epoch 4 in training:  95%|█████████▍| 179/189 [06:16<00:21,  2.10s/it]
# Epoch 4 in training:  95%|█████████▌| 180/189 [06:18<00:18,  2.11s/it]
# Epoch 4 in training:  96%|█████████▌| 181/189 [06:21<00:16,  2.10s/it]
# Epoch 4 in training:  96%|█████████▋| 182/189 [06:23<00:14,  2.11s/it]
# Epoch 4 in training:  97%|█████████▋| 183/189 [06:25<00:12,  2.11s/it]
# Epoch 4 in training:  97%|█████████▋| 184/189 [06:27<00:10,  2.11s/it]
# Epoch 4 in training:  98%|█████████▊| 185/189 [06:29<00:08,  2.12s/it]
# Epoch 4 in training:  98%|█████████▊| 186/189 [06:31<00:06,  2.12s/it]
# Epoch 4 in training:  99%|█████████▉| 187/189 [06:33<00:04,  2.13s/it]
# Epoch 4 in training:  99%|█████████▉| 188/189 [06:35<00:02,  2.13s/it]
# Epoch 4 in training: 100%|██████████| 189/189 [06:36<00:00,  1.81s/it]
# Training:  80%|████████  | 4/5 [34:43<07:45, 465.94s/it]
# Epoch 4/5 loss: 0.59
# Epoch 5 in training:   0%|          | 0/189 [00:00<?, ?it/s]
# Epoch 5 in training:   1%|          | 1/189 [00:02<06:29,  2.07s/it]
# Epoch 5 in training:   1%|          | 2/189 [00:04<06:29,  2.08s/it]
# Epoch 5 in training:   2%|▏         | 3/189 [00:06<06:35,  2.12s/it]
# Epoch 5 in training:   2%|▏         | 4/189 [00:08<06:36,  2.14s/it]
# Epoch 5 in training:   3%|▎         | 5/189 [00:10<06:32,  2.13s/it]
# Epoch 5 in training:   3%|▎         | 6/189 [00:12<06:27,  2.12s/it]
# Epoch 5 in training:   4%|▎         | 7/189 [00:14<06:24,  2.11s/it]
# Epoch 5 in training:   4%|▍         | 8/189 [00:16<06:21,  2.11s/it]
# Epoch 5 in training:   5%|▍         | 9/189 [00:19<06:18,  2.10s/it]
# Epoch 5 in training:   5%|▌         | 10/189 [00:21<06:17,  2.11s/it]
# Epoch 5 in training:   6%|▌         | 11/189 [00:23<06:11,  2.09s/it]
# Epoch 5 in training:   6%|▋         | 12/189 [00:25<06:10,  2.09s/it]
# Epoch 5 in training:   7%|▋         | 13/189 [00:27<06:10,  2.10s/it]
# Epoch 5 in training:   7%|▋         | 14/189 [00:29<06:08,  2.11s/it]
# Epoch 5 in training:  84%|████████▎ | 158/189 [05:32<01:06,  2.14s/it]
# Epoch 5 in training:  84%|████████▍ | 159/189 [05:34<01:03,  2.11s/it]
# Epoch 5 in training:  85%|████████▍ | 160/189 [05:37<01:01,  2.13s/it]
# Epoch 5 in training:  85%|████████▌ | 161/189 [05:39<00:59,  2.12s/it]
# Epoch 5 in training:  86%|████████▌ | 162/189 [05:41<00:56,  2.10s/it]
# Epoch 5 in training:  86%|████████▌ | 163/189 [05:43<00:54,  2.09s/it]
# Epoch 5 in training:  87%|████████▋ | 164/189 [05:45<00:51,  2.08s/it]
# Epoch 5 in training:  87%|████████▋ | 165/189 [05:47<00:49,  2.06s/it]
# Epoch 5 in training:  88%|████████▊ | 166/189 [05:49<00:47,  2.06s/it]
# Epoch 5 in training:  88%|████████▊ | 167/189 [05:51<00:45,  2.05s/it]
# Epoch 5 in training:  89%|████████▉ | 168/189 [05:53<00:42,  2.04s/it]
# Epoch 5 in training:  89%|████████▉ | 169/189 [05:55<00:40,  2.04s/it]
# Epoch 5 in training:  90%|████████▉ | 170/189 [05:57<00:38,  2.04s/it]
# Epoch 5 in training:  90%|█████████ | 171/189 [05:59<00:36,  2.05s/it]
# Epoch 5 in training:  91%|█████████ | 172/189 [06:01<00:34,  2.05s/it]
# Epoch 5 in training:  92%|█████████▏| 173/189 [06:03<00:32,  2.04s/it]
# Epoch 5 in training:  92%|█████████▏| 174/189 [06:05<00:30,  2.03s/it]
# Epoch 5 in training:  93%|█████████▎| 175/189 [06:07<00:28,  2.03s/it]
# Epoch 5 in training:  93%|█████████▎| 176/189 [06:09<00:26,  2.04s/it]
# Epoch 5 in training:  94%|█████████▎| 177/189 [06:11<00:24,  2.05s/it]
# Epoch 5 in training:  94%|█████████▍| 178/189 [06:13<00:22,  2.05s/it]
# Epoch 5 in training:  95%|█████████▍| 179/189 [06:15<00:20,  2.04s/it]
# Epoch 5 in training:  95%|█████████▌| 180/189 [06:17<00:18,  2.03s/it]
# Epoch 5 in training:  96%|█████████▌| 181/189 [06:19<00:16,  2.02s/it]
# Epoch 5 in training:  96%|█████████▋| 182/189 [06:21<00:14,  2.03s/it]
# Epoch 5 in training:  97%|█████████▋| 183/189 [06:23<00:12,  2.02s/it]
# Epoch 5 in training:  97%|█████████▋| 184/189 [06:25<00:10,  2.02s/it]
# Epoch 5 in training:  98%|█████████▊| 185/189 [06:27<00:08,  2.01s/it]
# Epoch 5 in training:  98%|█████████▊| 186/189 [06:29<00:05,  2.00s/it]
# Epoch 5 in training:  99%|█████████▉| 187/189 [06:31<00:04,  2.00s/it]
# Epoch 5 in training:  99%|█████████▉| 188/189 [06:33<00:02,  2.01s/it]
# Epoch 5 in training: 100%|██████████| 189/189 [06:35<00:00,  1.72s/it]
# Training: 100%|██████████| 5/5 [41:18<00:00, 495.80s/it]
# Epoch 5/5 loss: 0.58
# Testing: 100%|██████████| 48/48 [03:38<00:00,  4.56s/it]
# Test loss: 0.59
# Test accuracy: 66.71%

# %%
from sklearn.metrics import classification_report
